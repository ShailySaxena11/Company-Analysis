# %%
df=pd.read_csv(r"C:\Users\dell\Documents\PDFs\Staragile\pandas databasse\netflix daily top 10.csv");

# %%
df
# Out:
#           As of  Rank Year to Date Rank Last Week Rank  \
# 0      4/1/2020     1                 1              1
# 1      4/1/2020     2                 2              -
# 2      4/1/2020     3                 3              2
# 3      4/1/2020     4                 4              -
# 4      4/1/2020     5                 5              4
# ...         ...   ...               ...            ...
# 7095  3/11/2022     6                 5              1
# 7096  3/11/2022     7                 7              2
# 7097  3/11/2022     8                 8              -
# 7098  3/11/2022     9                 9              7
# 7099  3/11/2022    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
df.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %%
df.describe(include='O')
# Out:
#            As of Year to Date Rank Last Week Rank      Title     Type  \
# count       7100              7100           7100       7100     7100
# unique       710                11             11        645        4
# top     4/1/2020                 -              -  Cocomelon  TV Show
# freq          10               859           3968        428     4446
#
#        Netflix Exclusive Netflix Release Date
# count               4599                 7100
# unique                 1                  414
# top                  Yes             1-Jun-20
# freq                4599                  438

# %%
df.isna().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
df
# Out:
#           As of  Rank Year to Date Rank Last Week Rank  \
# 0      4/1/2020     1                 1              1
# 1      4/1/2020     2                 2              -
# 2      4/1/2020     3                 3              2
# 3      4/1/2020     4                 4              -
# 4      4/1/2020     5                 5              4
# ...         ...   ...               ...            ...
# 7095  3/11/2022     6                 5              1
# 7096  3/11/2022     7                 7              2
# 7097  3/11/2022     8                 8              -
# 7098  3/11/2022     9                 9              7
# 7099  3/11/2022    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %%
df1=df.drop(["As of","Rank","Last Week Rank"],axis=1)

# %%
df1
# Out:
#      Year to Date Rank                         Title     Type  \
# 0                    1  Tiger King: Murder, Mayhem …  TV Show
# 1                    2                         Ozark  TV Show
# 2                    3                  All American  TV Show
# 3                    4                  Blood Father    Movie
# 4                    5                  The Platform    Movie
# ...                ...                           ...      ...
# 7095                 5           Worst Roommate Ever  TV Show
# 7096                 7             Vikings: Valhalla  TV Show
# 7097                 8                       Shooter    Movie
# 7098                 9                       Shrek 2    Movie
# 7099                10                         Shrek    Movie
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 0                  Yes            20-Mar-20               9                90
# ...

# %%
sns.histplot(data=df1)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data=df1,x="Year to Date Rank",hue="Type")
# Out:
# <AxesSubplot:xlabel='Year to Date Rank', ylabel='Count'>

# %%
sns.countplot(x='Type', data=df1)
plt.title('Number of Shows by Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
sns.jointplot(data=df1,x="Type",y="Viewership Score")

# %%
sns.barplot(data=df1,y="Days In Top 10",x="Year to Date Rank")
# Out:
# <AxesSubplot:xlabel='Year to Date Rank', ylabel='Days In Top 10'>

# %%
sns.boxplot(data=df1,y="Viewership Score",x="Year to Date Rank")
# Out:
# <AxesSubplot:xlabel='Year to Date Rank', ylabel='Viewership Score'>

# %%
sns.lineplot(data=df1,y="Viewership Score",x="Type")
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Viewership Score'>

# %% [markdown]
# # There are maximun TV shows on netflix and most of the people like to watch TV shows, maximum year to date rank is 8
